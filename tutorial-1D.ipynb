# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import pyplint

# %% [markdown]
# ## Picard Lefschetz integral
# ### 1. define the funciton on exp

# %%
def phi_lens(x):
    nu = 10.0
    mu = 0.0
    o = (x-mu)**2/2 + 2/(1+x**2)
    o*= 1j*nu
    return o

# %% [markdown]
# ### 2. Instantiate the thimble class

# %%
thimble = pyplint.Thimble(-5, 5, delta=0.1, thre=-30, tau=0.05)

# %% [markdown]
# ### 3. Set function and run to get the thimble

# %%
thimble.set_phi(phi_lens)
thimble.run()

# %% [markdown]
# ### 4. plot thimble

# %%
# Set plot range by hand
thimble.plot((-2,2))

# %% [markdown]
# ### 5. Perform the integral on the thimble

# %%
# %time thimble.romberg()
# Out:
# CPU times: user 2.32 ms, sys: 0 ns, total: 2.32 ms
# Wall time: 2.32 ms
# (-74.82301982770596+51.37788184783848j)

# %% [markdown]
# ### Bonus: Make a gif of thimble evolution.

# %%
thimble.plot_gif('thimble.gif', xyrange=(-2,2))
